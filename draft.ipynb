# %% [markdown]
# ### Homelessness Data – Housing Inventory Count (HIC)and Point-in-Time Estimates (PIT)
#
# "These raw data sets contain Point-in-Time (PIT) estimates and national PIT estimates of homelessness as well as national estimates of homelessness by state and estimates of chronic homelessness from 2007 - 2022. Estimates of homeless veterans are also included beginning in 2011. The accompanying Housing Inventory Count (HIC) data is available as well from 2007 - 2021."
#
# Source: https://www.hudexchange.info/resource/3031/pit-and-hic-data-since-2007/

# %%
# !pip install pandas openpyxl requests
# Out:
# ...
#      |████████████████████████████████| 62 kB 2.4 MB/s eta 0:00:011
# ...
#      |████████████████████████████████| 124 kB 6.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 119 kB 19.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 61 kB 483 kB/s  eta 0:00:01
# ...
# WARNING: You are using pip version 21.1.1; however, version 23.3.1 is available.
# You should consider upgrading via the '/Users/nathantorento/.pyenv/versions/3.8.11/bin/python3.8 -m pip install --upgrade pip' command.

# %%
import pandas as pd

HICbyCoC_df = pd.read_excel('2007-2022-HIC-Counts-by-CoC.xlsx', header=1)
HICbyState_df = pd.read_excel('2007-2022-HIC-Counts-by-State.xlsx')
PITbyCoC_df = pd.read_excel('2007-2022-PIT-Counts-by-CoC.xlsx', header=1)
PITbyState_df = pd.read_excel('2007-2022-PIT-Counts-by-State.xlsx')

# %%
HICbyCoC_df.head()
# Out:
#   CoC Number  Total Year-Round Beds (ES, TH, SH)  \
# 0     AK-500                                2019
# 1     AK-501                                1069
# 2     AL-500                                 670
# 3     AL-501                                 467
# 4     AL-502                                 246
#
#    Total Non-DV Year-Round Beds (ES, TH, SH)  \
# 0                                       1952
# 1                                        595
# 2                                        640
# 3                                        391
# 4                                         56
#
#    Total HMIS Year-Round Beds (ES, TH, SH)  \
# 0                                     1872
# 1                                      567
# 2                                      552
# 3                                      391
# 4                                        0
#
#    HMIS Participation Rate for Year-Round Beds (ES, TH, SH)  \
# 0                                             0.9272
# ...

# %%
HICbyCoC_df

# %%
PITbyCoC_df.head()
# Out:
#    AK-500                                      Anchorage CoC  \
# 0  AK-501                        Alaska Balance of State CoC
# 1  AL-500  Birmingham/Jefferson, St. Clair, Shelby Counti...
# 2  AL-501            Mobile City & County/Baldwin County CoC
# 3  AL-502                     Florence/Northwest Alabama CoC
# 4  AL-503                       Huntsville/North Alabama CoC
#
#    Other Largely Urban CoC   1494    182   145   1167    571    914    8  ...  \
# 0        Largely Rural CoC  826.0  146.0  58.0  622.0  321.0  503.0  0.0  ...
# 1     Largely Suburban CoC  943.0   82.0  43.0  818.0  266.0  665.0  9.0  ...
# 2  Other Largely Urban CoC  585.0  148.0  30.0  407.0  230.0  352.0  2.0  ...
# 3        Largely Rural CoC  232.0   56.0  18.0  158.0  170.0   62.0  0.0  ...
# 4  Other Largely Urban CoC  549.0  106.0  38.0  405.0  231.0  314.0  1.0  ...
#
#    5.11  4.11  9.18  0.221  9.19  5.12  4.12  9.20  0.222  \
# 0   2.0   0.0   2.0    0.0   1.0   1.0   0.0   1.0    0.0
# ...

# %%
PITbyCoC_df

# %%
HICbyState_df.head()
# Out:
#   Unnamed: 0             Total Beds (ES, TH, SH)  \
# 0      State  Total Year-Round Beds (ES, TH, SH)
# 1         AK                                3088
# 2         AL                                2714
# 3         AR                                2318
# 4         AZ                                6162
#
#                                   Unnamed: 2  \
# 0  Total Non-DV Year-Round Beds (ES, TH, SH)
# 1                                       2547
# 2                                       2229
# 3                                       1787
# 4                                       5467
#
#                                 Unnamed: 3  \
# 0  Total HMIS Year-Round Beds (ES, TH, SH)
# 1                                     2439
# 2                                     1757
# 3                                     1117
# 4                                     5089
#
#                                           Unnamed: 4  \
# 0  HMIS Participation Rate for Year-Round Beds (E...
# ...

# %%
HICbyState_df[HICbyState_df['Unnamed: 0']=='CA']
# Out:
#   Unnamed: 0 Total Beds (ES, TH, SH) Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 5         CA                   68607      64427      52234     0.7614
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ...  \
# 5      52839      15134        634       9282      26344  ...
#
#   Other Permanent Housing (OPH) Unnamed: 68 Unnamed: 69 Unnamed: 70  \
# 5                         18377       18235       14878      0.8096
#
#   Unnamed: 71 Unnamed: 72 Unnamed: 73 Unnamed: 74 Unnamed: 75 Unnamed: 76
# 5        2102        6203       12167           7         526         487
#
# [1 rows x 77 columns]

# %%
PITbyState_df.head()
# Out:
#   State Change in Total Homelessness, 2021-2022  \
# 0    AK                                0.190354
# 1    AL                                0.467919
# 2    AR                                0.149603
# 3    AS
# 4    AZ                                1.482234
#
#   Change in Total Homelessness, 2020-2022  \
# 0                                0.190354
# 1                                0.119666
# 2                                0.039307
# 3
# 4                                0.234448
#
#   Change in Total Homelessness, 2019-2022  \
# 0                                 0.21657
# 1                                0.150567
# 2                               -0.094958
# 3
# 4                                0.354352
#
#   Change in Total Homelessness, 2018-2022  \
# 0                                0.150794
# 1                                0.092603
# 2                               -0.093289
# 3
# 4                                0.373847
#
#   Change in Total Homelessness, 2017-2022  \
# ...

# %%
PITbyState_df[PITbyState_df['State']=='CA']
# Out:
#   State Change in Total Homelessness, 2021-2022  \
# 5    CA                                1.984635
#
#   Change in Total Homelessness, 2020-2022  \
# 5                                0.061734
#
#   Change in Total Homelessness, 2019-2022  \
# 5                                0.133813
#
#   Change in Total Homelessness, 2018-2022  \
# 5                                0.319676
#
#   Change in Total Homelessness, 2017-2022  \
# 5                                0.304025
#
#   Change in Total Homelessness, 2016-2022  \
# 5                                0.451821
#
#   Change in Total Homelessness, 2015-2022  \
# 5                                0.481976
#
#   Change in Total Homelessness, 2014-2022  \
# 5                                0.505204
#
#   Change in Total Homelessness, 2013-2022  \
# 5                                  0.4468
#
#   Change in Total Homelessness, 2012-2022  \
# 5                                0.428175
#
#   Change in Total Homelessness, 2011-2022  \
# ...

# %% [markdown]
# ### Housing Dataset
# #### HOME VALUES
# Zillow Home Value Index (ZHVI): A measure of the typical home value and market changes across a given region and housing type. It reflects the typical value for homes in the 35th to 65th percentile range. Available as a smoothed, seasonally adjusted measure and as a raw measure.
# Zillow publishes top-tier ZHVI (\$, typical value for homes within the 65th to 95th percentile range for a given region) and bottom-tier ZHVI (\$, typical value for homes within the 5th to 35th percentile range for a given region).
# Zillow also publishes ZHVI for all single-family residences (\$, typical value for all single-family homes in a given region), for condo/coops (\$), for all homes with 1, 2, 3, 4 and 5+ bedrooms (\$), and the ZHVI per square foot (\$, typical value of all homes per square foot calculated by taking the estimated home value for each home in a given region and dividing it by the home’s square footage).
#
# Note: Starting with the January 2023 data release, and for all subsequent releases, the full ZHVI time series has been upgraded to harness the power of the neural Zestimate.
# More information about what ZHVI is and how it’s calculated is available on this overview page. Here’s a handy ZHVI User Guide for information about properly citing and making calculations with this metric.
#
#
# #### LIST AND SALE PRICES
# Median List Price: The median price at which homes across various geographies were listed.
# Median Sale Price: The median price at which homes across various geographies were sold.
#
# Source: https://www.zillow.com/research/data/

# %%
ZHVI_df = pd.read_csv('Metro_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv')
ZHVI_df.head()
# Out:
#    RegionID  SizeRank       RegionName RegionType StateName     2000-01-31  \
# 0    102001         0    United States    country       NaN  121428.348338
# 1    394913         1     New York, NY        msa        NY  216218.985144
# 2    753899         2  Los Angeles, CA        msa        CA  222303.044856
# 3    394463         3      Chicago, IL        msa        IL  152289.701354
# 4    394514         4       Dallas, TX        msa        TX  125341.331449
#
#       2000-02-29     2000-03-31     2000-04-30     2000-05-31  ...  \
# 0  121641.979730  121906.914111  122475.146355  123129.113541  ...
# 1  217137.793836  218065.112352  219944.218493  221890.097976  ...
# 2  223130.294238  224232.182526  226424.570068  228822.354722  ...
# 3  152430.677254  152699.168339  153367.107433  154170.557823  ...
# 4  125397.158916  125461.338304  125628.005434  125847.751482  ...
#
#       2022-12-31     2023-01-31     2023-02-28     2023-03-31     2023-04-30  \
# ...

# %%
ZHVI_df[ZHVI_df['RegionName']=='San Francisco, CA']
# Out:
#     RegionID  SizeRank         RegionName RegionType StateName     2000-01-31  \
# 12    395057        12  San Francisco, CA        msa        CA  290372.322628
#
#        2000-02-29     2000-03-31     2000-04-30     2000-05-31  ...  \
# 12  291508.200586  293239.380312  297935.843077  304408.404887  ...
#
#       2022-12-31    2023-01-31    2023-02-28    2023-03-31    2023-04-30  \
# 12  1.129304e+06  1.115008e+06  1.102845e+06  1.093993e+06  1.092180e+06
#
#       2023-05-31    2023-06-30    2023-07-31    2023-08-31    2023-09-30
# 12  1.094371e+06  1.099283e+06  1.106162e+06  1.114028e+06  1.121539e+06
#
# [1 rows x 290 columns]

# %%
ZHVI_df['RegionName'].value_counts()
# Out:
# RegionName
# United States               1
# Sidney, OH                  1
# Ozark, AL                   1
# Alice, TX                   1
# Gardnerville Ranchos, NV    1
#                            ..
# La Crosse, WI               1
# Napa, CA                    1
# Rapid City, SD              1
# Sumter, SC                  1
# Lamesa, TX                  1
# Name: count, Length: 895, dtype: int64

# %%
MLP_df = pd.read_csv('Metro_mlp_uc_sfrcondo_sm_month.csv')
MLP_df.head()
# Out:
#    RegionID  SizeRank       RegionName RegionType StateName  2018-03-31  \
# 0    102001         0    United States    country       NaN    263267.0
# 1    394913         1     New York, NY        msa        NY    503000.0
# 2    753899         2  Los Angeles, CA        msa        CA    721333.0
# 3    394463         3      Chicago, IL        msa        IL    284600.0
# 4    394514         4       Dallas, TX        msa        TX    322997.0
#
#    2018-04-30  2018-05-31  2018-06-30  2018-07-31  ...  2022-12-31  \
# 0    271267.0    276633.0    280000.0    280300.0  ...    375733.0
# 1    513000.0    521300.0    526300.0    528300.0  ...    619333.0
# 2    735000.0    743333.0    750000.0    749667.0  ...    887667.0
# 3    294600.0    300600.0    302267.0    301967.0  ...    302933.0
# 4    328497.0    331797.0    332800.0    329502.0  ...    403667.0
#
#    2023-01-31  2023-02-28  2023-03-31  2023-04-30  2023-05-31  2023-06-30  \
# ...

# %%
MLP_df[MLP_df['RegionName']=='San Francisco, CA']
# Out:
#     RegionID  SizeRank         RegionName RegionType StateName  2018-03-31  \
# 12    395057        12  San Francisco, CA        msa        CA    864333.0
#
#     2018-04-30  2018-05-31  2018-06-30  2018-07-31  ...  2022-12-31  \
# 12    907667.0    929000.0    936000.0    921333.0  ...    981333.0
#
#     2023-01-31  2023-02-28  2023-03-31  2023-04-30  2023-05-31  2023-06-30  \
# 12    964333.0    964333.0    989667.0   1036333.0   1070667.0   1085167.0
#
#     2023-07-31  2023-08-31  2023-09-30
# 12   1055167.0   1020833.0   1013000.0
#
# [1 rows x 72 columns]

# %%
# !pip install matplotlib geopandas
# Out:
# ...
# WARNING: You are using pip version 21.1.1; however, version 23.3.1 is available.
# You should consider upgrading via the '/Users/nathantorento/.pyenv/versions/3.8.11/bin/python3.8 -m pip install --upgrade pip' command.

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
# SF Analysis Neighborhoods
# Source: https://data.sfgov.org/Geographic-Locations-and-Boundaries/Analysis-Neighborhoods/p5b7-5n3h

analysis_gdf = gpd.read_file('analysis_neighborhoods.shp')
analysis_gdf.head(n=3)

# Plot the polygons and points
fig, ax = plt.subplots(figsize=(8, 6))
analysis_gdf.plot(ax=ax, color='blue', edgecolor='black', alpha=0.7, label='Polygons')
plt.xticks(rotation=45)  # Rotate x-axis labels by 45 degrees
ax.set_title('2022 Sampled Streets by SF Neighborhoods')
plt.show()

# %% [markdown]
# # Sammy's Dataset

# %%
# Homelessness
h_df = pd.read_csv('HomelessDataUSA.csv')
h_df.head()
# Out:
#   State  Number of CoCs Overall Homeless, 2022  \
# 0    AK               2                  2,320
# 1    AL               8                  3,752
# 2    AR               5                  2,459
# 3    AZ               3                 13,553
# 4    CA              44                171,521
#
#   Overall Homeless - Under 18, 2022 Overall Homeless - Age 18 to 24, 2022  \
# 0                               328                                   203
# 1                               790                                   217
# 2                               243                                   243
# 3                             1,723                                 1,084
# 4                            15,439                                10,896
#
#   Overall Homeless - Over 24, 2022 Overall Homeless - Female, 2022  \
# 0                            1,789                             892
# 1                            2,745                           1,633
# ...

# %%
# State Homelessness
sh_df = pd.read_excel('State Wise Homeless.xlsx')
sh_df.head()
# Out:
#   CoC Number                                           CoC Name  \
# 0     AK-500                                      Anchorage CoC
# 1     AK-501                        Alaska Balance of State CoC
# 2     AL-500  Birmingham/Jefferson, St. Clair, Shelby Counti...
# 3     AL-501            Mobile City & County/Baldwin County CoC
# 4     AL-502                     Florence/Northwest Alabama CoC
#
#               CoC Category  Overall Homeless, 2022  \
# 0  Other Largely Urban CoC                  1494.0
# 1        Largely Rural CoC                   826.0
# 2     Largely Suburban CoC                   943.0
# 3  Other Largely Urban CoC                   585.0
# 4        Largely Rural CoC                   232.0
#
#    Overall Homeless - Under 18, 2022  Overall Homeless - Age 18 to 24, 2022  \
# 0                              182.0                                  145.0
# 1                              146.0                                   58.0
# ...

# %%
# Monthly US Rentals
mr_df = pd.read_csv('Monthly US Rentals.csv')
mr_df.head()
# Out:
#    RegionID  SizeRank       RegionName RegionType StateName    1/31/2015  \
# 0    102001         0    United States    country       NaN  1280.633863
# 1    394913         1     New York, NY        msa        NY  2426.843124
# 2    753899         2  Los Angeles, CA        msa        CA  1897.597785
# 3    394463         3      Chicago, IL        msa        IL  1417.325728
# 4    394514         4       Dallas, TX        msa        TX  1139.808665
#
#      2/28/2015    3/31/2015    4/30/2015    5/31/2015  ...   12/31/2022  \
# 0  1287.501924  1296.645905  1306.721774  1316.751242  ...  1975.835739
# 1  2443.214185  2461.569551  2484.335192  2500.447307  ...  3192.662155
# 2  1909.296480  1924.702226  1939.356022  1954.717452  ...  2924.394108
# 3  1424.776246  1435.912190  1445.772642  1456.722898  ...  1860.947800
# 4  1144.828522  1152.963226  1163.690479  1174.252609  ...  1795.720424
#
#      1/31/2023    2/28/2023    3/31/2023    4/30/2023    5/31/2023  \
# ...

# %%
# Homelessness by Age
HbA_df_link = 'https://data.ca.gov/dataset/c7ed1ae4-4f93-4fc7-b603-3cd07a55d862/resource/b1a5ae24-5842-425c-b56c-aa90f8f1c767/download/experiencing_homelessness_age_demographics.csv'
HbA_df = pd.read_csv(HbA_df_link)
HbA_df.rename(columns={'EXPERIENCING_HOMELESSNESS_CNT': 'EXPERIENCING_HOMELESSNESS'}, inplace=True)

# %%
import pandas as pd
import requests
from io import BytesIO

# URL of the Excel file
median_sfh_prices_link = 'https://content.car.org/Public%20Products/Current%20Sales%20and%20Price/MedianPricesofExistingDetachedHomesHistoricalData.xlsx'
median_sfh_prices_df = pd.read_excel(BytesIO(requests.get(median_sfh_prices_link).content), skiprows=7)

# Convert "Mon-Yr" column to datetime format
median_sfh_prices_df['Mon-Yr'] = pd.to_datetime(median_sfh_prices_df['Mon-Yr'])

# Extract year from the "Mon-Yr" column and group by year, calculating the mean for each column
median_sfh_counties = median_sfh_prices_df.columns.difference(['Mon-Yr']) # get list of counties
median_sfh_prices_df = median_sfh_prices_df.groupby(median_sfh_prices_df['Mon-Yr'].dt.year)[median_sfh_counties].mean()

# Filter data from 2017 to the latest year
median_sfh_prices_df = median_sfh_prices_df.loc[2017:]

median_sfh_prices_df.head()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/core/groupby/groupby.py:1490, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1489 try:
# -> 1490     result = self.grouper._cython_operation(
#    1491         "aggregate",
#    1492         values,
#    1493         how,
#    1494         axis=data.ndim - 1,
#    1495         min_count=min_count,
#    1496         **kwargs,
#    1497     )
#    1498 except NotImplementedError:
#    1499     # generally if we have numeric_only=False
#    1500     # and non-applicable functions
#    1501     # try to python agg
#    1502     # TODO: shouldn't min_count matter?
#
# File ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/pandas/core/groupby/ops.py:959, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
# ...
